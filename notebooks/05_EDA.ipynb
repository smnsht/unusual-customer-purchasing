# %%
import pandas as pd

# %% [markdown]
# # 4 Customer-level diagnostics

# %% [markdown]
# Plot pie chart comparing all unique customers vs cancellations and non-cancellations.

# %%
# pd.Series(
#     {
#         "All": df["Customer ID"].value_counts().count(),
#         "Non-Cancellations": non_cancel_df["Customer ID"].value_counts().count(),        
#         "Cancellations": df_cancellations["Customer ID"].value_counts().count(),
#     }
# ).plot(
#     kind="bar", title="Number of Unique Customers in Non-Cancellations vs Cancellations"
# );

# %%
# Plot orders per customer distribution

#df_count_by_customer = df.groupby("Customer ID")["Invoice"].count()

# remove customer -1
#df_count_by_customer = df_count_by_customer[df_count_by_customer.index != -1]

# plot distribution of number of invoices per customer (log scale)
#df_count_by_customer.plot(kind="hist", bins=30, title="Distribution of Number of Invoices per Customer", logy=True);

# %%
# Plot distribution of total-spent per order

# calculate total sum per invoice for each invoice: group by invoice, multiply quantity by price, and sum the total for each invoice
#df_total_per_invoice = df.groupby("Invoice").apply(lambda x: (x["Quantity"] * x["Price"]).sum(), include_groups=False)

# plot distribution of total sum per invoice (log scale)
#df_total_per_invoice.plot(kind="hist", bins=25, title="Distribution of Total Sum per Invoice", logy=True);
